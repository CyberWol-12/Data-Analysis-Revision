# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.array([0,2,3,6,8,9])
b
# Out:
# array([0, 2, 3, 6, 8, 9])

# %%
a[0],a[1]
# Out:
# (np.int64(1), np.int64(2))

# %%
a[0:]
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[1:3]
# Out:
# array([2, 3])

# %%
a[1:-1]
# Out:
# array([2, 3, 4])

# %%
a[::2]
# Out:
# array([1, 3, 5])

# %%
b[0],b[2],b[-1]
# Out:
# (np.int64(0), np.int64(6), np.int64(9))

# %%
b[[0,2,-1]]
# Out:
# array([0, 3, 9])

# %% [markdown]
# Array Type

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b
# Out:
# array([0, 2, 3, 6, 8, 9])

# %%
b.dtype
# Out:
# dtype('int64')

# %%
np.array([1,2,3,4,5],dtype = np.int8)
# Out:
# array([1, 2, 3, 4, 5], dtype=int8)

# %% [markdown]
# Dimensions and shapes

# %%
A = np.array([
    [1,2,3],
    [5,6,7]
])

# %%
A.shape
# Out:
# (2, 3)

# %%
A.ndim
# Out:
# 2

# %%
A.size
# Out:
# 6

# %%
B = np.array([
    [
        [1,2,3],
        [6,7,8]
     ],
     [
        [12,34,56],
        [78,89,78]
     ]
])

# %%
B
# Out:
# array([[[ 1,  2,  3],
#         [ 6,  7,  8]],
#
#        [[12, 34, 56],
#         [78, 89, 78]]])

# %%
B.shape
# Out:
# (2, 2, 3)

# %%
B.ndim
# Out:
# 3

# %%
B.size
# Out:
# 12
