# %%
import pandas as pd
import numpy as np

# %%
g7_pop = pd.Series([34.34,45.56,67.89,56.90,23.56,45,67.8])
g7_pop
# Out:
# 0    34.34
# 1    45.56
# 2    67.89
# 3    56.90
# 4    23.56
# 5    45.00
# 6    67.80
# dtype: float64

# %%
g7_pop.name = 'G7   p   opulation in millions'
g7_pop
# Out:
# 0    34.34
# 1    45.56
# 2    67.89
# 3    56.90
# 4    23.56
# 5    45.00
# 6    67.80
# Name: G7   p   opulation in millions, dtype: float64

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
g7_pop.index = [
    'Cananda',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United State',
]

# %%
g7_pop
# Out:
# Cananda           34.34
# France            45.56
# Germany           67.89
# Italy             56.90
# Japan             23.56
# United Kingdom    45.00
# United State      67.80
# Name: G7   p   opulation in millions, dtype: float64
